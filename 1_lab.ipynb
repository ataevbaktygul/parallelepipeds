# %% [markdown]
# <a href="https://colab.research.google.com/github/ataevbaktygul/parallelepipeds/blob/main/1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seminar_1
# ## Calculations with python

# %% [markdown]
# Пайтон славится простотой математических вычислений
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Task_1
#
# ## Вычислите

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jhgjhg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Task_2
#
# Даны 2 переменные. Определите их тип данных.

# %%
x = 24
y = 31.4

# %% [markdown]
# # Task_3
#
# Cоздайте переменные $a$ и $b$ и присвойте им любые целые числа.
#
# В переменную $diff$ сохраните разницу между этими числами в абсолютном значении. Отобразите содержимое полученной переменной.

# %% [markdown]
# # Task_4
#
# Перед вами лежит куча с картошкой в которой 290 кг. Вам нужно разложить это все по мешкам. При этом в каждый мешок помещается 25 кг.
#
#
#
# 1.   Сколько мешков будет заполнено полностью?
# 2.   Сколько килограмм картошки из той, которой не хватит на заполнение последнего мешка, останется?

# %% [markdown]
# # Task_5
#
# ## Time_delta
#
# Сантехник Василий приехал на объект в 13:25 и начал работать. Закончил работать он в 19:40. Ему стало интересно, сколько времени он проработал на объекте. Давайте напишем программу, которая это расчитает.
#
# В переменных h_1 и m_1 хранится время начала работы, а в переменных h_2 и m_2 время завершение работы.
#
# Количество часов и минут, которые проведет за работой Василий сохраните в переменные h и m.

# %%
h_1 = 13
m_1 = 25

h_2 = 19
h_2 = 40

# %%
#your code

# %% [markdown]
# # Task_6
#
# Ниже написан код, который получает с клавиатуры два числа - старую и новую стоимость некоторого товара и сохраняет их в отдельные переменные. Функционал функции input() мы разберем немного позже.

# %%
old_price = int(input('Write old price: '))
new_price = int(input('Write new price: '))
# Out:
# Write old price: 240
# Write new price: 540

# %% [markdown]
# Напишите программу, которая нам сообщит, на сколько процентов новая цена отличается от старой. Чтобы не получать больших дробей, округлите результат с точностью до одного знака после запятой. При этом следует учесть, что новая цена может быть как выше так и ниже старой. Полученное значение сохраните в переменную 'res'.

# %% [markdown]
# # Task_7
#
# Теперь попробуем применить импортируемый модуль 'math'.

# %%
import math as mt

# %% [markdown]
# Данный код нам теперь позволит вызывать отдельные функции этого модуля кратко обращаясь к нему как 'mt.'
#
# Пример:
#
#
#
# ```
# mt.sqrt() # Квадратный корень
#
# mt.cos() # Косинус числа (Принимает радианы)
#
# mt.exp() # Экспонента
#
# mt.log() # Логарифмическая функция
#
# mt.pi # Число Пи
#
# mt.e # Число Эйлера
#
# mt.floor() # Округление в меньшую сторону
#
# mt.ceil() # Округление в большую сторону
# ```

# %% [markdown]
# Вычислите значение выражения:
#
# $$y = e^{(\frac{1}{1 + \cos^2{x}})} $$

# %%
x = 2
y = ...

# %% [markdown]
# # Task_8
#
# Задача.
#
# Некоторое предприятие получает заказ на производство 1500 деталей. Один оператор обрабатывающего комплекса в состоянии выполнить за смену 45 деталей. Сколько необходимо рабочих постов задействовать под выпуск данных деталей чтобы выполнить заказ за одну смену. Ответ сохраните в переменную 'res'

# %%
# your code...

# %%
# после решения задачи запустите сей код
print(f'Для выполнения заказа необходимо задействовать {res} поста.')

# %% [markdown]
# # Task_9
#
# Вспомним прямоугольный треугольник. Напишем код, который запрашивает длины катетов и гипотенузы.

# %%
katet_1 = int(input('Введите длину катета: '))
katet_2 = int(input('Введите длину катета: '))
gip = int(input('Введите длину гипотенузы: '))

# %% [markdown]
# Теперь, когда мы получили три переменные, расчитаем синус наименьшего острого угла треугольника.
#
# Стоит помнить функции max(), min()
#
#
#
# ```
# max(2, 5)
# >>> 5
#
# min(2, 5)
# >>> 2
# ```

# %% [markdown]
# # Task_10
#
# Для такого же треугольника из предыдущей задачи вычислите значение меньшего острого угла в градусах.
#
# Для этого вам пригодится функция, импортированная из 'math', арксинус.
#
#
#
# ```
# math.asin()
# ```
#
# Это функция, которая получает на вход значение синуса и возвращает значение угла в радианах!!!
#
# Чтобы перевести угол из радиан в градусы, можно применить данную формулу:
#
# $\alpha_{deg} = \frac{\alpha_{rad}*180}{\pi}$

# %%
katet_1 = int(input('Введите длину катета: '))
katet_2 = int(input('Введите длину катета: '))
gip = int(input('Введите длину гипотенузы: '))
